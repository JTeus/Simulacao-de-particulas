# %% [markdown]
# ## Configuração do Jupyter Nootebook

# %%
from IPython.display import display, HTML
from IPython.display import display, Markdown
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %% [markdown]
# ## Pacotes utilizados

# %%
import pyspedas
import numpy as np
import matplotlib.pyplot as plt
params = {'tex.usetex': True}
import matplotlib.dates as md


from pytplot import get_data,store_data, timebar,tplot, tplot_names
from pyspedas import time_string, time_double, mms
from pyspedas.mms import curlometer 
from matplotlib.colors import LogNorm
from datetime import datetime 

import pandas as pd
from pandas import Series, DataFrame

# Magic commands 
#https://ipython.readthedocs.io/en/stable/interactive/magics.html#cell-magics

# %matplotlib inline             
# %matplotlib notebook

# %% [markdown]
# ## Configurações do evento

# %%
start_time = '2015-12-01/09:00:00'
end_time   = '2015-12-01/09:30:00'

ttext = start_time.split('/')       # Separar os parâmetros de entrada  data"/"hora

probe = ['1','2','3','4']
datatype=['dis-moms','des-moms']
t_clip = 'True'

data_rate_fgm = 'srvy'
data_rate_fpi = 'fast'

cgeo = 'gse'

# %% [markdown]
# ## Carregamento dos instrumentos da MMS

# %%
var_mec = ['mms1_mec_r_'+cgeo, 
           'mms2_mec_r_'+cgeo, 
           'mms3_mec_r_'+cgeo, 
           'mms4_mec_r_'+cgeo]

var_fpi = ['mms1_dis_numberdensity_'+data_rate_fpi,
           'mms1_dis_bulkv_'+cgeo+'_'+data_rate_fpi,
           'mms1_dis_energyspectr_omni_'+data_rate_fpi,
           'mms1_des_tempperp_'+data_rate_fpi,'mms1_des_temppara_'+data_rate_fpi,
           'mms1_dis_tempperp_'+data_rate_fpi, 'mms1_dis_temppara_'+data_rate_fpi]

var_fgm = ['mms1_fgm_b_'+cgeo+'_'+data_rate_fgm+'_l2',
           'mms2_fgm_b_'+cgeo+'_'+data_rate_fgm+'_l2',
           'mms3_fgm_b_'+cgeo+'_'+data_rate_fgm+'_l2',
           'mms4_fgm_b_'+cgeo+'_'+data_rate_fgm+'_l2']

var_edp = ['mms1_edp_dce_'+cgeo+'_'+data_rate_fpi+'_l2']

# %% [markdown]
# ## MEC - Magnetic Ephemeris Coordinates

# %% [markdown]
# * https://pyspedas.readthedocs.io/en/latest/mms.html#magnetic-ephemeris-coordinates-mec

# %%
pyspedas.mms.mec(trange=[start_time,end_time] , probe=probe, 
                 varnames = var_mec  , time_clip=t_clip)
# Out:
# 20-Jul-23 15:19:14: Loading pydata\mms1\mec\srvy\l2\epht89q\2015\12\mms1_mec_srvy_l2_epht89q_20151201_v2.1.0.cdf
# 20-Jul-23 15:19:14: Loading pydata\mms2\mec\srvy\l2\epht89q\2015\12\mms2_mec_srvy_l2_epht89q_20151201_v2.1.0.cdf
# 20-Jul-23 15:19:14: Loading pydata\mms3\mec\srvy\l2\epht89q\2015\12\mms3_mec_srvy_l2_epht89q_20151201_v2.1.0.cdf
# 20-Jul-23 15:19:15: Loading pydata\mms4\mec\srvy\l2\epht89q\2015\12\mms4_mec_srvy_l2_epht89q_20151201_v2.1.0.cdf
# 20-Jul-23 15:19:15: Time clip was applied to: mms1_mec_r_gse
# 20-Jul-23 15:19:15: Time clip was applied to: mms2_mec_r_gse
# 20-Jul-23 15:19:15: Time clip was applied to: mms3_mec_r_gse
# 20-Jul-23 15:19:15: Time clip was applied to: mms4_mec_r_gse
# 20-Jul-23 15:19:15: Loaded variables:
# 20-Jul-23 15:19:15: mms1_mec_r_gse
# 20-Jul-23 15:19:15: mms2_mec_r_gse
# 20-Jul-23 15:19:15: mms3_mec_r_gse
# 20-Jul-23 15:19:15: mms4_mec_r_gse
# ['mms1_mec_r_gse', 'mms2_mec_r_gse', 'mms3_mec_r_gse', 'mms4_mec_r_gse']

# %% [markdown]
# ## FGM - Fluxgate Magnetometer

# %% [markdown]
# * https://pyspedas.readthedocs.io/en/latest/mms.html#fluxgate-magnetometer-fgm

# %%
pyspedas.mms.fgm(trange=[start_time,end_time] , probe=probe,  
                 varnames = var_fgm, data_rate= data_rate_fgm ,time_clip=t_clip)
# Out:
# 20-Jul-23 15:19:16: Loading pydata\mms1\fgm\srvy\l2\2015\12\mms1_fgm_srvy_l2_20151201_v4.18.0.cdf
# 20-Jul-23 15:19:16: Loading pydata\mms2\fgm\srvy\l2\2015\12\mms2_fgm_srvy_l2_20151201_v4.18.0.cdf
# 20-Jul-23 15:19:16: Loading pydata\mms3\fgm\srvy\l2\2015\12\mms3_fgm_srvy_l2_20151201_v4.18.0.cdf
# 20-Jul-23 15:19:16: Loading pydata\mms4\fgm\srvy\l2\2015\12\mms4_fgm_srvy_l2_20151201_v4.18.0.cdf
# 20-Jul-23 15:19:23: Time clip was applied to: mms1_fgm_b_gse_srvy_l2
# 20-Jul-23 15:19:24: Time clip was applied to: mms2_fgm_b_gse_srvy_l2
# 20-Jul-23 15:19:25: Time clip was applied to: mms3_fgm_b_gse_srvy_l2
# 20-Jul-23 15:19:25: Time clip was applied to: mms4_fgm_b_gse_srvy_l2
# 20-Jul-23 15:19:25: Loaded variables:
# 20-Jul-23 15:19:25: mms1_fgm_b_gse_srvy_l2
# 20-Jul-23 15:19:25: mms2_fgm_b_gse_srvy_l2
# 20-Jul-23 15:19:25: mms3_fgm_b_gse_srvy_l2
# 20-Jul-23 15:19:25: mms4_fgm_b_gse_srvy_l2
# 20-Jul-23 15:19:25: mms1_fgm_b_gse_srvy_l2_bvec
# 20-Jul-23 15:19:25: mms1_fgm_b_gse_srvy_l2_btot
# 20-Jul-23 15:19:25: mms2_fgm_b_gse_srvy_l2_bvec
# 20-Jul-23 15:19:25: mms2_fgm_b_gse_srvy_l2_btot
# 20-Jul-23 15:19:25: mms3_fgm_b_gse_srvy_l2_bvec
# 20-Jul-23 15:19:25: mms3_fgm_b_gse_srvy_l2_btot
# 20-Jul-23 15:19:25: mms4_fgm_b_gse_srvy_l2_bvec
# 20-Jul-23 15:19:25: mms4_fgm_b_gse_srvy_l2_btot
# ['mms1_fgm_b_gse_srvy_l2',
#  'mms2_fgm_b_gse_srvy_l2',
#  'mms3_fgm_b_gse_srvy_l2',
#  'mms4_fgm_b_gse_srvy_l2',
#  'mms1_fgm_b_gse_srvy_l2_bvec',
#  'mms1_fgm_b_gse_srvy_l2_btot',
#  'mms2_fgm_b_gse_srvy_l2_bvec',
#  'mms2_fgm_b_gse_srvy_l2_btot',
#  'mms3_fgm_b_gse_srvy_l2_bvec',
#  'mms3_fgm_b_gse_srvy_l2_btot',
#  'mms4_fgm_b_gse_srvy_l2_bvec',
#  'mms4_fgm_b_gse_srvy_l2_btot']

# %% [markdown]
# ## FPI - Fast Plasma Investigation (FPI)

# %% [markdown]
# * https://pyspedas.readthedocs.io/en/latest/mms.html#fast-plasma-investigation-fpi

# %%
pyspedas.mms.fpi(trange=[start_time, end_time], probe=probe,
                 datatype=datatype, varnames= var_fpi, 
                 data_rate= data_rate_fpi, time_clip=t_clip)
# Out:
# 20-Jul-23 15:19:26: Loading pydata\mms1\fpi\fast\l2\dis-moms\2015\12\mms1_fpi_fast_l2_dis-moms_20151201080000_v3.4.0.cdf
# 20-Jul-23 15:19:26: Loading pydata\mms1\fpi\fast\l2\des-moms\2015\12\mms1_fpi_fast_l2_des-moms_20151201080000_v3.4.0.cdf
# 20-Jul-23 15:19:26: Loading pydata\mms2\fpi\fast\l2\dis-moms\2015\12\mms2_fpi_fast_l2_dis-moms_20151201080000_v3.4.0.cdf
# 20-Jul-23 15:19:27: Loading pydata\mms2\fpi\fast\l2\des-moms\2015\12\mms2_fpi_fast_l2_des-moms_20151201080000_v3.4.0.cdf
# 20-Jul-23 15:19:27: Loading pydata\mms3\fpi\fast\l2\dis-moms\2015\12\mms3_fpi_fast_l2_dis-moms_20151201080000_v3.4.0.cdf
# 20-Jul-23 15:19:27: Loading pydata\mms3\fpi\fast\l2\des-moms\2015\12\mms3_fpi_fast_l2_des-moms_20151201080000_v3.4.0.cdf
# 20-Jul-23 15:19:27: Loading pydata\mms4\fpi\fast\l2\dis-moms\2015\12\mms4_fpi_fast_l2_dis-moms_20151201080000_v3.4.0.cdf
# 20-Jul-23 15:19:27: Loading pydata\mms4\fpi\fast\l2\des-moms\2015\12\mms4_fpi_fast_l2_des-moms_20151201080000_v3.4.0.cdf
# 20-Jul-23 15:19:27: Time clip was applied to: mms1_des_tempperp_fast
# 20-Jul-23 15:19:27: Time clip was applied to: mms1_des_temppara_fast
# 20-Jul-23 15:19:27: Time clip was applied to: mms1_dis_numberdensity_fast
# 20-Jul-23 15:19:27: Time clip was applied to: mms1_dis_bulkv_gse_fast
# 20-Jul-23 15:19:27: Time clip was applied to: mms1_dis_energyspectr_omni_fast
# 20-Jul-23 15:19:27: Time clip was applied to: mms1_dis_tempperp_fast
# 20-Jul-23 15:19:27: Time clip was applied to: mms1_dis_temppara_fast
# 20-Jul-23 15:19:27: The name mms1_des_errorflags_fast is currently not in pytplot
# 20-Jul-23 15:19:27: The name mms1_des_compressionloss_fast is currently not in pytplot
# 20-Jul-23 15:19:27: The name mms2_des_errorflags_fast is currently not in pytplot
# 20-Jul-23 15:19:27: The name mms2_des_compressionloss_fast is currently not in pytplot
# 20-Jul-23 15:19:27: The name mms3_des_errorflags_fast is currently not in pytplot
# 20-Jul-23 15:19:27: The name mms3_des_compressionloss_fast is currently not in pytplot
# 20-Jul-23 15:19:27: The name mms4_des_errorflags_fast is currently not in pytplot
# 20-Jul-23 15:19:27: The name mms4_des_compressionloss_fast is currently not in pytplot
# 20-Jul-23 15:19:27: The name mms1_dis_errorflags_fast is currently not in pytplot
# 20-Jul-23 15:19:27: The name mms1_dis_compressionloss_fast is currently not in pytplot
# 20-Jul-23 15:19:27: The name mms2_dis_errorflags_fast is currently not in pytplot
# 20-Jul-23 15:19:27: The name mms2_dis_compressionloss_fast is currently not in pytplot
# 20-Jul-23 15:19:27: The name mms3_dis_errorflags_fast is currently not in pytplot
# 20-Jul-23 15:19:27: The name mms3_dis_compressionloss_fast is currently not in pytplot
# 20-Jul-23 15:19:27: The name mms4_dis_errorflags_fast is currently not in pytplot
# 20-Jul-23 15:19:27: The name mms4_dis_compressionloss_fast is currently not in pytplot
# 20-Jul-23 15:19:27: The name mms1_dis_pitchangdist_lowen_fast is currently not in pytplot
# 20-Jul-23 15:19:27: The name mms1_dis_pitchangdist_miden_fast is currently not in pytplot
# 20-Jul-23 15:19:27: The name mms1_dis_pitchangdist_highen_fast is currently not in pytplot
# 20-Jul-23 15:19:27: The name mms1_dis_errorflags_fast_moms is currently not in pytplot
# 20-Jul-23 15:19:27: The name mms1_dis_errorflags_fast_moms is currently not in pytplot
# 20-Jul-23 15:19:27: The name mms1_des_pitchangdist_lowen_fast is currently not in pytplot
# 20-Jul-23 15:19:27: The name mms1_des_pitchangdist_miden_fast is currently not in pytplot
# 20-Jul-23 15:19:27: The name mms1_des_pitchangdist_highen_fast is currently not in pytplot
# 20-Jul-23 15:19:27: The name mms1_des_errorflags_fast_moms is currently not in pytplot
# 20-Jul-23 15:19:27: The name mms1_des_errorflags_fast_moms is currently not in pytplot
# 20-Jul-23 15:19:27: The name mms2_dis_pitchangdist_lowen_fast is currently not in pytplot
# 20-Jul-23 15:19:27: The name mms2_dis_pitchangdist_miden_fast is currently not in pytplot
# 20-Jul-23 15:19:27: The name mms2_dis_pitchangdist_highen_fast is currently not in pytplot
# 20-Jul-23 15:19:27: The name mms2_dis_errorflags_fast_moms is currently not in pytplot
# 20-Jul-23 15:19:27: The name mms2_dis_errorflags_fast_moms is currently not in pytplot
# 20-Jul-23 15:19:27: The name mms2_des_pitchangdist_lowen_fast is currently not in pytplot
# 20-Jul-23 15:19:27: The name mms2_des_pitchangdist_miden_fast is currently not in pytplot
# 20-Jul-23 15:19:27: The name mms2_des_pitchangdist_highen_fast is currently not in pytplot
# 20-Jul-23 15:19:27: The name mms2_des_errorflags_fast_moms is currently not in pytplot
# 20-Jul-23 15:19:27: The name mms2_des_errorflags_fast_moms is currently not in pytplot
# 20-Jul-23 15:19:27: The name mms3_dis_pitchangdist_lowen_fast is currently not in pytplot
# 20-Jul-23 15:19:27: The name mms3_dis_pitchangdist_miden_fast is currently not in pytplot
# 20-Jul-23 15:19:27: The name mms3_dis_pitchangdist_highen_fast is currently not in pytplot
# 20-Jul-23 15:19:27: The name mms3_dis_errorflags_fast_moms is currently not in pytplot
# 20-Jul-23 15:19:27: The name mms3_dis_errorflags_fast_moms is currently not in pytplot
# 20-Jul-23 15:19:27: The name mms3_des_pitchangdist_lowen_fast is currently not in pytplot
# 20-Jul-23 15:19:27: The name mms3_des_pitchangdist_miden_fast is currently not in pytplot
# 20-Jul-23 15:19:27: The name mms3_des_pitchangdist_highen_fast is currently not in pytplot
# 20-Jul-23 15:19:27: The name mms3_des_errorflags_fast_moms is currently not in pytplot
# 20-Jul-23 15:19:27: The name mms3_des_errorflags_fast_moms is currently not in pytplot
# 20-Jul-23 15:19:27: The name mms4_dis_pitchangdist_lowen_fast is currently not in pytplot
# 20-Jul-23 15:19:27: The name mms4_dis_pitchangdist_miden_fast is currently not in pytplot
# 20-Jul-23 15:19:27: The name mms4_dis_pitchangdist_highen_fast is currently not in pytplot
# 20-Jul-23 15:19:27: The name mms4_dis_errorflags_fast_moms is currently not in pytplot
# 20-Jul-23 15:19:27: The name mms4_dis_errorflags_fast_moms is currently not in pytplot
# 20-Jul-23 15:19:27: The name mms4_des_pitchangdist_lowen_fast is currently not in pytplot
# 20-Jul-23 15:19:27: The name mms4_des_pitchangdist_miden_fast is currently not in pytplot
# 20-Jul-23 15:19:27: The name mms4_des_pitchangdist_highen_fast is currently not in pytplot
# 20-Jul-23 15:19:27: The name mms4_des_errorflags_fast_moms is currently not in pytplot
# 20-Jul-23 15:19:27: The name mms4_des_errorflags_fast_moms is currently not in pytplot
# 20-Jul-23 15:19:27: Loaded variables:
# 20-Jul-23 15:19:27: mms1_des_tempperp_fast
# 20-Jul-23 15:19:27: mms1_des_temppara_fast
# 20-Jul-23 15:19:27: mms1_dis_numberdensity_fast
# 20-Jul-23 15:19:27: mms1_dis_bulkv_gse_fast
# 20-Jul-23 15:19:27: mms1_dis_energyspectr_omni_fast
# 20-Jul-23 15:19:27: mms1_dis_tempperp_fast
# 20-Jul-23 15:19:27: mms1_dis_temppara_fast
# 20-Jul-23 15:19:27: mms1_des_errorflags_fast_moms
# 20-Jul-23 15:19:27: mms1_des_compressionloss_fast_moms
# 20-Jul-23 15:19:27: mms2_des_errorflags_fast_moms
# 20-Jul-23 15:19:27: mms2_des_compressionloss_fast_moms
# 20-Jul-23 15:19:27: mms3_des_errorflags_fast_moms
# 20-Jul-23 15:19:27: mms3_des_compressionloss_fast_moms
# 20-Jul-23 15:19:27: mms4_des_errorflags_fast_moms
# 20-Jul-23 15:19:27: mms4_des_compressionloss_fast_moms
# 20-Jul-23 15:19:27: mms1_dis_errorflags_fast_moms
# 20-Jul-23 15:19:27: mms1_dis_compressionloss_fast_moms
# 20-Jul-23 15:19:27: mms2_dis_errorflags_fast_moms
# 20-Jul-23 15:19:27: mms2_dis_compressionloss_fast_moms
# 20-Jul-23 15:19:27: mms3_dis_errorflags_fast_moms
# 20-Jul-23 15:19:27: mms3_dis_compressionloss_fast_moms
# 20-Jul-23 15:19:27: mms4_dis_errorflags_fast_moms
# 20-Jul-23 15:19:27: mms4_dis_compressionloss_fast_moms
# ['mms1_des_tempperp_fast',
#  'mms1_des_temppara_fast',
#  'mms1_dis_numberdensity_fast',
#  'mms1_dis_bulkv_gse_fast',
#  'mms1_dis_energyspectr_omni_fast',
#  'mms1_dis_tempperp_fast',
#  'mms1_dis_temppara_fast',
#  'mms1_des_errorflags_fast_moms',
#  'mms1_des_compressionloss_fast_moms',
#  'mms2_des_errorflags_fast_moms',
#  'mms2_des_compressionloss_fast_moms',
#  'mms3_des_errorflags_fast_moms',
#  'mms3_des_compressionloss_fast_moms',
#  'mms4_des_errorflags_fast_moms',
#  'mms4_des_compressionloss_fast_moms',
#  'mms1_dis_errorflags_fast_moms',
#  'mms1_dis_compressionloss_fast_moms',
#  'mms2_dis_errorflags_fast_moms',
#  'mms2_dis_compressionloss_fast_moms',
#  'mms3_dis_errorflags_fast_moms',
#  'mms3_dis_compressionloss_fast_moms',
#  'mms4_dis_errorflags_fast_moms',
#  'mms4_dis_compressionloss_fast_moms']

# %% [markdown]
# ## EDP - Electric field Double Probe (EDP)

# %% [markdown]
# * https://pyspedas.readthedocs.io/en/latest/mms.html#electric-field-double-probe-edp

# %%
pyspedas.mms.edp(trange=[start_time,end_time], varnames = var_edp, probe=probe)
# Out:
# 20-Jul-23 15:19:28: Loading pydata\mms1\edp\fast\l2\dce\2015\12\mms1_edp_fast_l2_dce_20151201_v2.1.0.cdf
# 20-Jul-23 15:19:28: Loading pydata\mms2\edp\fast\l2\dce\2015\12\mms2_edp_fast_l2_dce_20151201_v2.1.0.cdf
# 20-Jul-23 15:19:29: Loading pydata\mms3\edp\fast\l2\dce\2015\12\mms3_edp_fast_l2_dce_20151201_v2.1.0.cdf
# 20-Jul-23 15:19:29: Loading pydata\mms4\edp\fast\l2\dce\2015\12\mms4_edp_fast_l2_dce_20151201_v2.1.0.cdf
# 20-Jul-23 15:19:32: Time clip was applied to: mms1_edp_dce_gse_fast_l2
# 20-Jul-23 15:19:32: Loaded variables:
# 20-Jul-23 15:19:32: mms1_edp_dce_gse_fast_l2
# ['mms1_edp_dce_gse_fast_l2']

# %% [markdown]
# ## Curlometer calculations

# %% [markdown]
# https://github.com/spedas/mms-examples/blob/master/basic/Curlometer%20Technique.ipynb

# %% [markdown]
# https://github.com/spedas/mms-examples/blob/master/advanced/FPI_curlometer.ipynb

# %%
positions = ['mms1_mec_r_gse', 'mms2_mec_r_gse', 'mms3_mec_r_gse',
             'mms4_mec_r_gse']
fields = ['mms1_fgm_b_'+cgeo+'_'+data_rate_fgm+'_l2', 
          'mms2_fgm_b_'+cgeo+'_'+data_rate_fgm+'_l2', 
          'mms3_fgm_b_'+cgeo+'_'+data_rate_fgm+'_l2', 
          'mms4_fgm_b_'+cgeo+'_'+data_rate_fgm+'_l2']

curlometer_vars = curlometer(fields=fields, positions=positions)
# Out:
# 20-Jul-23 15:19:32: tinterpol (linear) was applied to: mms2_fgm_b_gse_srvy_l2_i
# 20-Jul-23 15:19:32: tinterpol (linear) was applied to: mms3_fgm_b_gse_srvy_l2_i
# 20-Jul-23 15:19:32: tinterpol (linear) was applied to: mms4_fgm_b_gse_srvy_l2_i
# 20-Jul-23 15:19:32: tinterpol (linear) was applied to: mms1_mec_r_gse_i
# 20-Jul-23 15:19:32: tinterpol (linear) was applied to: mms2_mec_r_gse_i
# 20-Jul-23 15:19:32: tinterpol (linear) was applied to: mms3_mec_r_gse_i
# 20-Jul-23 15:19:32: tinterpol (linear) was applied to: mms4_mec_r_gse_i

# %%
curlometer_vars        # Variáveis geradas pelo método curlometer
# Out:
# ['baryb', 'curlB', 'divB', 'jtotal', 'jpar', 'jperp', 'alpha', 'alphaparallel']

# %%
t_j, j = get_data('jtotal')   # Aquisição da densidade de corrente 
                              # total(em componentes) 
                              # através do método curlometer

# %% [markdown]
# ## Extração dos dados

# %%
# Variáveis fgm 

## Campo magnético    
t1_gse, b1 = get_data('mms1_fgm_b_'+cgeo+'_'+data_rate_fgm+'_l2')

# Variáveis do edi 
t1_edp, e1 = get_data('mms1_edp_dce_'+cgeo+'_'+data_rate_fpi+'_l2')

# variáveis fpi 

## densidade numérica
t1_fpi, d1 = get_data('mms1_dis_numberdensity_'+data_rate_fpi)

## Velocidade
t1_v, v1   = get_data('mms1_dis_bulkv_'+cgeo+'_'+data_rate_fpi)

## Espectro de energia
t1_i , data1_i, energy1_i= get_data('mms1_dis_energyspectr_omni_'+data_rate_fpi)

## Variaveis mec
t1_p, pos1 = get_data('mms1_mec_r_gse')

pos1_r = pos1/6371.2

# %%
#Algumas construções 

v1_t = np.zeros(len(v1));
j_t  = np.zeros(len(j)); 
e_t  = np.zeros(len(e1));
p_t  = np.zeros(len(pos1_r))

# Construção do v_total
for i in range(len(v1)):
    v1_t[i] = np.linalg.norm(v1[i,:]) 

#Construção do J_total
for i in range(len(j)):
    j_t[i] = np.linalg.norm(j[i,:]) 
    
#Construção do e_total
for i in range(len(e1)):
    e_t[i] = np.linalg.norm(e1[i,:])

# Construção da posição
for i in range(len(pos1_r)):
    p_t[i] = np.linalg.norm(pos1_r[i,:])
    
## Temperatura dos íons e dos elétrons para MMS1
T_e1pr, T_epr = get_data('mms1_des_tempperp_'+data_rate_fpi)
T_e1pl, T_epl = get_data('mms1_des_temppara_'+data_rate_fpi)

T_i1pr, T_ipr = get_data('mms1_dis_tempperp_'+data_rate_fpi)
T_i1pl, T_ipl = get_data('mms1_dis_temppara_'+data_rate_fpi)
    
dis_T = (T_ipl + 2*T_ipr)/3.0 
des_T = (T_epl + 2*T_epr)/3.0

# %%
#Escrever os dados de posição da sonda com 3 casas decimais
pos1_r = np.round(pos1_r,3)
pos1_r
# Out:
# array([[11.657,  1.246, -0.986],
#        [11.654,  1.251, -0.986],
#        [11.652,  1.255, -0.986],
#        [11.649,  1.259, -0.986],
#        [11.647,  1.264, -0.986],
#        [11.644,  1.268, -0.986],
#        [11.642,  1.273, -0.986],
#        [11.639,  1.277, -0.986],
#        [11.637,  1.281, -0.986],
#        [11.634,  1.286, -0.986],
#        [11.631,  1.29 , -0.986],
#        [11.629,  1.294, -0.986],
#        [11.626,  1.299, -0.986],
#        [11.624,  1.303, -0.986],
#        [11.621,  1.307, -0.986],
#        [11.618,  1.312, -0.986],
#        [11.616,  1.316, -0.987],
#        [11.613,  1.32 , -0.987],
#        [11.61 ,  1.325, -0.987],
#        [11.608,  1.329, -0.987],
#        [11.605,  1.333, -0.987],
#        [11.602,  1.338, -0.987],
#        [11.599,  1.342, -0.987],
#        [11.597,  1.346, -0.987],
#        [11.594,  1.351, -0.987],
#        [11.591,  1.355, -0.987],
#        [11.588,  1.359, -0.987],
#        [11.586,  1.364, -0.987],
#        [11.583,  1.368, -0.987],
#        [11.58 ,  1.372, -0.987],
#        [11.577,  1.377, -0.987],
#        [11.575,  1.381, -0.987],
#        [11.572,  1.385, -0.987],
#        [11.569,  1.39 , -0.987],
#        [11.566,  1.394, -0.987],
#        [11.563,  1.398, -0.987],
#        [11.56 ,  1.403, -0.987],
#        [11.557,  1.407, -0.987],
#        [11.555,  1.411, -0.987],
#        [11.552,  1.416, -0.987],
#        [11.549,  1.42 , -0.987],
#        [11.546,  1.424, -0.987],
#        [11.543,  1.429, -0.987],
#        [11.54 ,  1.433, -0.987],
#        [11.537,  1.437, -0.987],
#        [11.534,  1.441, -0.987],
#        [11.531,  1.446, -0.987],
#        [11.528,  1.45 , -0.987],
#        [11.525,  1.454, -0.987],
#        [11.522,  1.459, -0.987],
#        [11.519,  1.463, -0.987],
#        [11.516,  1.467, -0.987],
#        [11.513,  1.472, -0.987],
#        [11.51 ,  1.476, -0.987],
#        [11.507,  1.48 , -0.987],
#        [11.504,  1.484, -0.987],
#        [11.501,  1.489, -0.987],
#        [11.498,  1.493, -0.987],
#        [11.495,  1.497, -0.987],
#        [11.492,  1.502, -0.987],
#        [11.489,  1.506, -0.987]])

# %% [markdown]
# ## Ajuste dos dados de Tempo

# %%
# Ajuste dos valores de tempo para o plot (Não mexer após a primeira iteração)

# Campo magnético
t1 = md.date2num(time_string(t1_gse))

#Campo elétrico 
t1_e = md.date2num(time_string(t1_edp))

#J
t1_j = md.date2num(time_string(t_j))

# Dados de plasma
t1_d = md.date2num(time_string(t1_fpi))
t1_v  = md.date2num(time_string(t1_v))
t1_en = md.date2num(time_string(t1_i)) 

# Dados de posição

t_p1 = md.date2num(time_string(t1_p))

# %% [markdown]
# ## Etapa de finalização

# %%
# Intervalo Total do plot
IT1 = '09:19:00'
IT2 = '09:21:30'

# Primeiro par de barras verticais (inferior e superior)
IB11 = '09:19:26'
IB12 = '09:19:36'

# Segundo par de barras verticais (inferior e superior)
IB21 = '09:20:47'
IB22 = '09:20:57'

#######################################################################################
tb_inf = md.date2num(datetime.strptime(start_time[0:11]+IT1, '%Y-%m-%d/%H:%M:%S')) 
tb_sup = md.date2num(datetime.strptime(end_time[0:11]+IT2, '%Y-%m-%d/%H:%M:%S')) 

tb_i1 = md.date2num(datetime.strptime(start_time[0:11]+ IB11, '%Y-%m-%d/%H:%M:%S')) 
tb_s1 = md.date2num(datetime.strptime(end_time[0:11]+ IB12, '%Y-%m-%d/%H:%M:%S')) 

tb_i2 = md.date2num(datetime.strptime(start_time[0:11]+ IB21, '%Y-%m-%d/%H:%M:%S')) 
tb_s2 = md.date2num(datetime.strptime(end_time[0:11]+ IB22, '%Y-%m-%d/%H:%M:%S'))

# %% [markdown]
# # Gráficos

# %% [markdown]
# ## ----- Seleção do plot

# %%
plt_todos = str(input('Exibir as componentes de B, V e J ? (S/N): '))   
# "s" para plotar todas as componentes de campo magnético, velocidade e densidade de corrente.
# Out:
# Exibir as componentes de B, V e J ? (S/N): s

# %%
#Plot 
nxs = 6
plt.rcParams['axes.autolimit_mode'] = 'round_numbers' #Arredondar os ticks das extremidades

fig, axs = plt.subplots(nxs, gridspec_kw={'hspace': 0.07},figsize=(15,20))
axs[0].set_title('FGM & FPI - MMS 1'+10*' '+ttext[0],size = 20)

seconds = md.SecondLocator(interval=10)   
minutes = md.MinuteLocator(interval=1)  
formatter = md.DateFormatter('%H:%M')  #'%H.%M'

for n in range(0,nxs):   
    # Barras verticais
    axs[n].axvline(tb_i1 , color='black',lw=1)
    axs[n].axvline(tb_s1 , color='black',lw=1)
    
    axs[n].axvline(tb_i2 , color='black',lw=1)
    axs[n].axvline(tb_s2 , color='black',lw=1)
    
    # Eixo x
    axs[n].xaxis.set_major_locator(minutes)
    axs[n].xaxis.set_major_formatter(formatter)
    axs[n].xaxis.set_minor_locator(seconds)
    axs[n].set_xlim(tb_inf,tb_sup)
    
    #Aumento do tamanho do label dos gráficos
    axs[n].tick_params(axis='x',labelsize=15)
    axs[n].tick_params(axis='y',labelsize=11)
    
    axs[n].label_outer()
    
if plt_todos.lower() == 's':
    
    # Componentes do campo magnético
    axs[0].plot(t1, b1[:,0], color='blue' ,label= r'$B_X$')
    axs[0].plot(t1, b1[:,1], color='green',label= r'$B_Y$')
    axs[0].plot(t1, b1[:,2], color='red'  ,label= r'$B_Z$')
    
    # Componentes da densidade de corrente
    axs[1].plot(t1_j, j[:,0]/1e-6, color='blue' ,label= r'$J_X$')
    axs[1].plot(t1_j, j[:,1]/1e-6, color='green',label= r'$J_Y$')
    axs[1].plot(t1_j, j[:,2]/1e-6, color='red'  ,label= r'$J_Z$')
    
    # Componentes da velocidade dos íons
    axs[3].plot(t1_v, v1[:,0],'-*', color='blue' , label= r'$V_X$')
    axs[3].plot(t1_v, v1[:,1],'-*', color='green', label= r'$V_Y$')
    axs[3].plot(t1_v, v1[:,2],'-*', color='red'  , label= r'$V_Z$')
       
# Plot do campo magnético total
axs[0].plot(t1, b1[:,3], color='black',label= r'$B_T$')
axs[0].axhline(0, color='black',lw = 2,linestyle=":")

axs[0].legend(loc=(1.01,.2) ,title= '',frameon = False, prop={'size':15})
axs[0].set_ylabel('B \n FGM-GSE \n [nT]', labelpad=10,size = 18)
axs[0].annotate('a)', xy=(0.97,0.85), xycoords='axes fraction',size=18)

axs[0].grid(linewidth=0.5)
axs[0].set_yticks(np.arange(-50., 50.1, 10))
axs[0].set_ylim([-50.1,50.1])

#Plot do j_total
axs[1].plot(t1_j, j_t[:]/1e-6, color='black',label= r'$J_T$')
axs[1].axhline(0, color='black',lw = 2,linestyle=":")

axs[1].legend(loc=(1.01,.2) ,title= '',frameon = False, prop={'size':15})
axs[1].set_ylabel('J \n Curl-GSE \n '+r'$\left[\dfrac{A}{m^2} \times 10^{-6}\right]$',labelpad=10, size = 18)
axs[1].annotate('b)', xy=(0.97,0.85), xycoords='axes fraction',size=18)

axs[1].grid()
axs[1].set_yticks(np.arange(-1.5, 2.1, 0.5))
axs[1].set_ylim([-1.6,2.2])

#Plot de densidade
axs[2].plot(t1_d, d1,'-*', color='black')

axs[2].set_ylabel('N ION \n'+ r'$\left[ cm^{-3} \right]$',labelpad=10, size = 18)
axs[2].annotate('c)', xy=(0.97,0.85), xycoords='axes fraction',size=18)
axs[2].set_ylim([0,60])
axs[2].set_yticks(np.arange(0,60.1,5))
axs[2].grid(which='both',linewidth=0.5)

# Plot da velocidade
axs[3].plot(t1_v, v1_t[:],'-*', color='black', label= r'$V_T$')

axs[3].legend(loc=(1.01,.2),title= '', frameon = False, prop={'size':15})
axs[3].set_ylabel('V ION \n GSE \n'+ r'$ \left[ \dfrac{km}{s} \right]$',labelpad=10, size = 18)
axs[3].annotate('d)', xy=(0.97,0.85), xycoords='axes fraction',size=18)
axs[3].grid(which='both',linewidth=0.5)
axs[3].axhline(0, color='black',lw = 2,linestyle=":")

axs[3].set_ylim([-600,600])
axs[3].set_yticks(np.arange(-600,600.1,100))

# Plot da temperatura dos íons e dos elétrons
axs[4].plot(t1_d, dis_T,'-*',color='red', label='Íons')
#axs[4].plot(t1_d, dis_T*11600/1e6,'-*',color='red', label='Íons')
#axs[4].plot(t1_d, des_T*11600/1e6,'-*',color='blue',label='Elétrons')

#axs[4].set_ylabel('T ION \n'+ r'$\left[ \times 10^6  K \right]$',labelpad=10, size = 18)
axs[4].set_ylabel('T ION \n'+ r'$eV$',labelpad=10, size = 18)
axs[4].annotate('e)', xy=(0.97,0.85), xycoords='axes fraction',size=18)
axs[4].legend(loc=(1.01,.5) ,title= '',frameon = False, prop={'size':15})
axs[4].grid(which='both',linewidth=0.5)

axs[4].set_ylim([0,700])
axs[4].set_yticks(np.arange(0,700,50))

# Plot do espectro de energia

c = axs[5].pcolor(t1_en,np.transpose(energy1_i),np.transpose(data1_i), shading='auto', 
                  norm=LogNorm(vmin=1e4, vmax=1e8), cmap='jet')
axs[5].set_yscale('log') 
axs[5].set_ylabel('ION eSpec \n [eV]',labelpad=10, size = 18)
axs[5].annotate('f)', xy=(0.97,0.85), xycoords='axes fraction',size=18)

axs[5].set_ylim([10e0,3*1e4])

cbaxes = fig.add_axes([0.92, 0.125, 0.03, 0.104]) 
fig.colorbar(c, ax = axs[3], cax = cbaxes, label = '[keV / '+ r'(cm$^2$ s sr keV)]') 

################################# Configuração dos eixos de posição da sonda 

axs2 = axs[5].twiny()
axs2.xaxis.set_ticks_position('bottom') # set the position of the second x-axis to bottom
axs2.xaxis.set_label_position('bottom') # set the position of the second x-axis to bottom
axs2.spines['bottom'].set_position(('outward', 36))
axs2.set_xticklabels(pos1_r[:,0], color='blue')
axs2.set_xlabel(r'$X_{GSE}[R_E]$', loc='right', color='blue')

axs3 = axs2.twiny()
axs3.xaxis.set_ticks_position('bottom')
axs3.xaxis.set_label_position('bottom') # set the position of the second x-axis to bottom
axs3.spines['bottom'].set_position(('outward', 72))

axs3.set_xticklabels(pos1_r[:,1], color='green')
axs3.set_xlabel(r'$Y_{GSE}[R_E]$', loc='right', color= 'green')

axs4 = axs3.twiny()
axs4.xaxis.set_ticks_position('bottom')
axs4.xaxis.set_label_position('bottom') # set the position of the second x-axis to bottom
axs4.spines['bottom'].set_position(('outward', 108))
axs4.set_xticklabels(pos1_r[:,2], color='red')
axs4.set_xlabel(r'$Z_{GSE}[R_E]$', loc='right',color='red')

#plt.savefig('MMS1_01122015_comJ.png', dpi=300, bbox_inches = 'tight')   # Salvamento da figura
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1500">
# 20-Jul-23 15:20:00: C:\Users\mathe\AppData\Local\Temp\ipykernel_6640\2182962985.py:126: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs2.set_xticklabels(pos1_r[:,0], color='blue')
#
# 20-Jul-23 15:20:00: C:\Users\mathe\AppData\Local\Temp\ipykernel_6640\2182962985.py:134: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs3.set_xticklabels(pos1_r[:,1], color='green')
#
# 20-Jul-23 15:20:00: C:\Users\mathe\AppData\Local\Temp\ipykernel_6640\2182962985.py:141: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs4.set_xticklabels(pos1_r[:,2], color='red')

# %% [markdown]
# * ## Região pré-shock (1)

# %% [markdown]
# * ## Achar os índices

# %%
def IVal(v,init,fim):
    
    tam = len(v)
    t   = np.zeros((tam, 2))
    i   = np.zeros((1, 2))
    
    for ii in range(tam):
        
        t[ii, 0] = np.abs(init - v[ii])
        t[ii, 1] = np.abs(fim - v[ii])   
    
    i[0,0] = t[:,0].argmin()
    i[0,1] = t[:,1].argmin()
    
    return i

# %%
tim = [t1, t1_d, t1_v, t1_j, t_p1]

ips1 = np.zeros((len(tim),2))

for j in range(len(tim)):
    
    ips1[j] = IVal(tim[j], tb_i1, tb_s1)

# %% [markdown]
# * ## Médias

# %%
b1_m  = [ np.mean(b1[round(ips1[0][0]): round(ips1[0][1])+1,0]),
          np.mean(b1[round(ips1[0][0]): round(ips1[0][1])+1,1]),
          np.mean(b1[round(ips1[0][0]): round(ips1[0][1])+1,2])
                                         ]
B1_m  = np.mean(b1[ round(ips1[0][0]): round(ips1[0][1])+1,3])

v1_m  = [np.mean(v1[round(ips1[2][0]): round(ips1[2][1])+1,0]),
          np.mean(v1[round(ips1[2][0]): round(ips1[2][1])+1,1]),
          np.mean(v1[round(ips1[2][0]): round(ips1[2][1])+1,2])
                                         ]
v1_tm  = np.mean(v1_t[round(ips1[2][0]):round(ips1[2][1])+1])

d1_m  = np.mean(d1[round(ips1[1][0]):round(ips1[1][1])+1])
T1_mi = np.mean(dis_T[round(ips1[1][0]):round(ips1[1][1])+1])
T1_me = np.mean(des_T[round(ips1[1][0]):round(ips1[1][1])+1])

pos1_mr  = pos1_r[round(ips1[-1][0]),:]

# %% [markdown]
# * ## Região pós-shock (2)

# %% [markdown]
# * ## Achar os índices

# %%
tim = [t1, t1_d, t1_v, t1_j, t_p1]

ips2 = np.zeros((len(tim),2))

for j in range(len(tim)):
    
    ips2[j] = IVal(tim[j], tb_i2, tb_s2)

# %% [markdown]
# * ## Médias

# %%
b2_m  = [np.mean( b1[round(ips2[0][0]): round(ips2[0][1])+1,0]),
          np.mean(b1[round(ips2[0][0]): round(ips2[0][1])+1,1]),
          np.mean(b1[round(ips2[0][0]): round(ips2[0][1])+1,2])
                                         ]
B2_m  = np.mean(b1[ round(ips2[0][0]): round(ips2[0][1])+1,3])

v2_m  = [np.mean( v1[round(ips2[2][0]): round(ips2[2][1])+1,0]),
          np.mean(v1[round(ips2[2][0]): round(ips2[2][1])+1,1]),
          np.mean(v1[round(ips2[2][0]): round(ips2[2][1])+1,2])
                                         ]
v2_tm  = np.mean(v1_t[round(ips2[2][0]):round(ips2[2][1])+1])

d2_m  = np.mean(d1[round(ips2[1][0]):round(ips2[1][1])+1])
T2_mi = np.mean(dis_T[round(ips2[1][0]):round(ips2[1][1])+1])
T2_me = np.mean(des_T[round(ips2[1][0]):round(ips2[1][1])+1])

pos2_mr  = pos1_r[round(ips2[-1][0]),:]

# %% [markdown]
# # Resumo

# %%
print('---------------------------------Valores no vento solar-----------------------------------------')
print('------------------------------------------------------------------------------------------------')
print('Bx[nT]\t By[nT]\t Bz[nT]\t Bt[nT]\t d[cm^-3]   T[eV]    Vx[km/s]  Vy[km/s]  Vz[km/s]  VT[km/s]')
print('------------------------------------------------------------------------------------------------')
print('%2.2f  \t%  2.2f \t%2.2f \t %2.2f \t   %2.2f   %2.2e   %2.2f    %2.2f   %2.2f    %2.2f'%(b1_m[0],
                                                                                                b1_m[1],
                                                                                                b1_m[2],
                                                                                                B1_m,
                                                                                                d1_m,
                                                                                                T1_mi,
                                                                                                v1_m[0],
                                                                                                v1_m[1],
                                                                                                v1_m[2],
                                                                                                v1_tm))
# Out:
# ---------------------------------Valores no vento solar-----------------------------------------
# ------------------------------------------------------------------------------------------------
# Bx[nT]	 By[nT]	 Bz[nT]	 Bt[nT]	 d[cm^-3]   T[eV]    Vx[km/s]  Vy[km/s]  Vz[km/s]  VT[km/s]
# ------------------------------------------------------------------------------------------------
# -3.20  	-5.11 	-1.59 	 6.27 	   7.94   7.57e+01   -500.75    52.87   -17.03    503.87

# %%
print('-------------------------------Valores na bainha magnética--------------------------------------')
print('------------------------------------------------------------------------------------------------')
print('Bx[nT]\t By[nT]\t Bz[nT]\t Bt[nT]\t d[cm^-3]   T[eV]    Vx[km/s]  Vy[km/s]  Vz[km/s]  VT[km/s]')
print('------------------------------------------------------------------------------------------------')
print('%2.2f  \t%  2.2f \t %2.2f\t %2.2f\t   %2.2f   %2.2e  %2.2f   %2.2f    %2.2f     %2.2f'%(b2_m[0],
                                                                                               b2_m[1],
                                                                                               b2_m[2],
                                                                                               B2_m,
                                                                                               d2_m,
                                                                                               T2_mi,
                                                                                               v2_m[0],
                                                                                               v2_m[1],
                                                                                               v2_m[2],
                                                                                               v2_tm))
# Out:
# -------------------------------Valores na bainha magnética--------------------------------------
# ------------------------------------------------------------------------------------------------
# Bx[nT]	 By[nT]	 Bz[nT]	 Bt[nT]	 d[cm^-3]   T[eV]    Vx[km/s]  Vy[km/s]  Vz[km/s]  VT[km/s]
# ------------------------------------------------------------------------------------------------
# -8.14  	-8.07 	 -10.85	 16.79	   32.35   5.29e+02  -161.46   70.09    -88.45     197.70

# %% [markdown]
# * ## $[B]= B_2 - B_1$

# %%
DB = np.array(b2_m)-np.array(b1_m)
DB
# Out:
# array([-4.942361 , -2.9661174, -9.25972  ], dtype=float32)

# %% [markdown]
# * ## $[V] = V_2 - V_1$

# %%
DV = np.array(v2_m)-np.array(v1_m)
DV
# Out:
# array([339.28442 ,  17.215939, -71.41542 ], dtype=float32)

# %% [markdown]
# * # Cálculo do vetor normal $n$ (usando $[B]$, $[V]$ e $[B]$)
#     ## Mixed data 3

# %%
n   = np.cross(np.cross(DB,DV),DB)
n_m = n/np.linalg.norm(n)

n_m
# Out:
# array([ 0.8855696, -0.0281544, -0.4636528], dtype=float32)

# %%
cos_m = np.dot(n_m, b1_m)/(B1_m)
o_nm  = np.arccos(cos_m)*(180/np.pi)

180 - o_nm
# Out:
# 71.88397940138437

# %%
plt_todos = str(input('Exibir as componentes de B, V e J ? (S/N): '))   
# "s" para plotar todas as componentes de campo magnético, velocidade e densidade de corrente.
# Out:
# Exibir as componentes de B, V e J ? (S/N): N

# %%
#Plot 
nxs = 6
plt.rcParams['axes.autolimit_mode'] = 'round_numbers' #Arredondar os ticks das extremidades

fig, axs = plt.subplots(nxs, gridspec_kw={'hspace': 0.07},figsize=(15,20))
axs[0].set_title('FGM & FPI - MMS 1'+10*' '+ttext[0],size = 20)

seconds = md.SecondLocator(interval=10)   
minutes = md.MinuteLocator(interval=1)  
formatter = md.DateFormatter('%H:%M')  #'%H.%M'

for n in range(0,nxs):   
    # Barras verticais
    axs[n].axvline(tb_i1 , color='black',lw=1)
    axs[n].axvline(tb_s1 , color='black',lw=1)
    
    axs[n].axvline(tb_i2 , color='black',lw=1)
    axs[n].axvline(tb_s2 , color='black',lw=1)
    
    # Eixo x
    axs[n].xaxis.set_major_locator(minutes)
    axs[n].xaxis.set_major_formatter(formatter)
    axs[n].xaxis.set_minor_locator(seconds)
    axs[n].set_xlim(tb_inf,tb_sup)
    
    #Aumento do tamanho do label dos gráficos
    axs[n].tick_params(axis='x',labelsize=15)
    axs[n].tick_params(axis='y',labelsize=11)
    
    axs[n].label_outer()
    
if plt_todos.lower() == 's':
    
    # Componentes do campo magnético
    axs[0].plot(t1, b1[:,0], color='blue' ,label= r'$B_X$')
    axs[0].plot(t1, b1[:,1], color='green',label= r'$B_Y$')
    axs[0].plot(t1, b1[:,2], color='red'  ,label= r'$B_Z$')
    
    # Componentes da densidade de corrente
    axs[1].plot(t1_j, j[:,0]/1e-6, color='blue' ,label= r'$J_X$')
    axs[1].plot(t1_j, j[:,1]/1e-6, color='green',label= r'$J_Y$')
    axs[1].plot(t1_j, j[:,2]/1e-6, color='red'  ,label= r'$J_Z$')
    
    # Componentes da velocidade dos íons
    axs[3].plot(t1_v, v1[:,0], color='blue' , label= r'$V_X$')
    axs[3].plot(t1_v, v1[:,1], color='green', label= r'$V_Y$')
    axs[3].plot(t1_v, v1[:,2], color='red'  , label= r'$V_Z$')
    
    
    
# Plot do campo magnético total
axs[0].plot(t1, b1[:,3], color='black',label= r'$B_T$')
axs[0].axhline(0, color='black',lw = 2,linestyle=":")

axs[0].legend(loc=(1.01,.2) ,title= '',frameon = False, prop={'size':15})
axs[0].set_ylabel('B \n FGM-GSE \n [nT]', labelpad=10,size = 18)
axs[0].annotate('a)', xy=(0.97,0.85), xycoords='axes fraction',size=18)

axs[0].grid(linewidth=0.5)
axs[0].set_yticks(np.arange(-50., 50.1, 10))
axs[0].set_ylim([-50.1,50.1])


#Plot do j_total
axs[1].plot(t1_j, j_t[:]/1e-6, color='black',label= r'$J_T$')
axs[1].axhline(0, color='black',lw = 2,linestyle=":")

axs[1].legend(loc=(1.01,.2) ,title= '',frameon = False, prop={'size':15})
axs[1].set_ylabel('J \n Curl-GSE \n '+r'$\left[\dfrac{A}{m^2} \times 10^{-6}\right]$',labelpad=10, size = 18)
axs[1].annotate('b)', xy=(0.97,0.85), xycoords='axes fraction',size=18)

axs[1].grid()
axs[1].set_yticks(np.arange(-1.5, 2.1, 0.5))
axs[1].set_ylim([-1.6,2.2])

#Plot de densidade
axs[2].plot(t1_d, d1,'-*', color='black')

axs[2].set_ylabel('N ION \n'+ r'$\left[ cm^{-3} \right]$',labelpad=10, size = 18)
axs[2].annotate('c)', xy=(0.97,0.85), xycoords='axes fraction',size=18)
axs[2].set_ylim([0,60])
axs[2].set_yticks(np.arange(0,60.1,5))
axs[2].grid(which='both',linewidth=0.5)

# Plot da velocidade
axs[3].plot(t1_v, v1_t[:], color='black', label= r'$V_T$')

axs[3].legend(loc=(1.01,.2),title= '', frameon = False, prop={'size':15})
axs[3].set_ylabel('V ION \n GSE \n'+ r'$ \left[ \dfrac{km}{s} \right]$',labelpad=10, size = 18)
axs[3].annotate('d)', xy=(0.97,0.85), xycoords='axes fraction',size=18)
axs[3].grid(which='both',linewidth=0.5)
axs[3].axhline(0, color='black',lw = 2,linestyle=":")

axs[3].set_ylim([-600,600])
axs[3].set_yticks(np.arange(-600,600.1,100))

# Plot da temperatura dos íons e dos elétrons
axs[4].plot(t1_d, dis_T*11600/1e6,'-*',color='red', label='Íons')
axs[4].plot(t1_d, des_T*11600/1e6,'-*',color='blue',label='Elétrons')

axs[4].set_ylabel('T ION \n'+ r'$\left[ \times 10^6  K \right]$',labelpad=10, size = 18)
axs[4].annotate('e)', xy=(0.97,0.85), xycoords='axes fraction',size=18)
axs[4].legend(loc=(1.01,.5) ,title= '',frameon = False, prop={'size':15})
axs[4].grid(which='both',linewidth=0.5)

axs[4].set_ylim([0,8])
axs[4].set_yticks(np.arange(0,8.1,0.5))

# Plot do espectro de energia

c = axs[5].pcolor(t1_en,np.transpose(energy1_i),np.transpose(data1_i), shading='auto', 
                  norm=LogNorm(vmin=1e4, vmax=1e8), cmap='jet')
axs[5].set_yscale('log') 
axs[5].set_ylabel('ION eSpec \n [eV]',labelpad=10, size = 18)
axs[5].annotate('f)', xy=(0.97,0.85), xycoords='axes fraction',size=18)

axs[5].set_ylim([10e0,3*1e4])

cbaxes = fig.add_axes([0.92, 0.125, 0.03, 0.104]) 
fig.colorbar(c, ax = axs[3], cax = cbaxes, label = '[keV / '+ r'(cm$^2$ s sr keV)]') 

################################# Configuração dos eixos de posição da sonda 

axs2 = axs[5].twiny()
axs2.xaxis.set_ticks_position('bottom') # set the position of the second x-axis to bottom
axs2.xaxis.set_label_position('bottom') # set the position of the second x-axis to bottom
axs2.spines['bottom'].set_position(('outward', 36))
axs2.set_xticklabels(pos1_r[:,0], color='blue')
axs2.set_xlabel(r'$X_{GSE}[R_E]$', loc='right', color='blue')

axs3 = axs2.twiny()
axs3.xaxis.set_ticks_position('bottom')
axs3.xaxis.set_label_position('bottom') # set the position of the second x-axis to bottom
axs3.spines['bottom'].set_position(('outward', 72))

axs3.set_xticklabels(pos1_r[:,1], color='green')
axs3.set_xlabel(r'$Y_{GSE}[R_E]$', loc='right', color= 'green')

axs4 = axs3.twiny()
axs4.xaxis.set_ticks_position('bottom')
axs4.xaxis.set_label_position('bottom') # set the position of the second x-axis to bottom
axs4.spines['bottom'].set_position(('outward', 108))
axs4.set_xticklabels(pos1_r[:,2], color='red')
axs4.set_xlabel(r'$Z_{GSE}[R_E]$', loc='right',color='red')

#plt.savefig('MMS1_comJ.png', dpi=300, bbox_inches = 'tight')   # Salvamento da figura
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1500">
# 20-Jul-23 15:20:04: C:\Users\mathe\AppData\Local\Temp\ipykernel_6640\2779985458.py:127: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs2.set_xticklabels(pos1_r[:,0], color='blue')
#
# 20-Jul-23 15:20:04: C:\Users\mathe\AppData\Local\Temp\ipykernel_6640\2779985458.py:135: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs3.set_xticklabels(pos1_r[:,1], color='green')
#
# 20-Jul-23 15:20:04: C:\Users\mathe\AppData\Local\Temp\ipykernel_6640\2779985458.py:142: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs4.set_xticklabels(pos1_r[:,2], color='red')
